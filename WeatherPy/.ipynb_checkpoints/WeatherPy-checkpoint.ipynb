# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import random

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed = ([] for i in range(9))
weather_data = dict()

for index, c in enumerate(cities, start=1):
    max_attempts = 10
    attempts = 0
    while attempts < max_attempts:
        url = "https://api.openweathermap.org/data/2.5/weather?q=" + c + "&appid=" + weather_api_key
        response = requests.get(url).json()
        if response['cod'] == 200:
            print(f'Processing record {index}, {c}')
            city.append(response['name'])
            cloudiness.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            max_temp.append(response['main']['temp_max'])
            wind_speed.append(response['wind']['speed'])
            break

        elif response['cod'] == 429:
            print('API request limit, back off for 60 sec')  
            time.sleep((60) + random.random())
            attempts = attempts + 1

        else:
            print('City not found, skipping')
            break    

weather_data['City'] = city
weather_data['Cloudiness'] = cloudiness
weather_data['Country'] = country
weather_data['Date'] = date
weather_data['Humidity'] = humidity
weather_data['Lat'] = lat 
weather_data['Lng'] = lng
weather_data['Max Temp'] = max_temp
weather_data['Wind Speed'] = wind_speed
print('Completed!')
# Out:
# Processing record 1, mahajanga
# Processing record 2, lloydminster
# Processing record 3, salalah
# Processing record 4, dikson
# Processing record 5, seoul
# Processing record 6, cape town
# Processing record 7, coquimbo
# Processing record 8, ponta do sol
# City not found, skipping
# Processing record 10, bambous virieux
# Processing record 11, qaanaaq
# Processing record 12, farafenni
# Processing record 13, rikitea
# Processing record 14, mataura
# City not found, skipping
# City not found, skipping
# Processing record 17, vostok
# Processing record 18, kapaa
# Processing record 19, ushuaia
# Processing record 20, buala
# Processing record 21, balfour
# Processing record 22, requena
# Processing record 23, hermanus
# Processing record 24, muzhi
# Processing record 25, harper
# Processing record 26, hobart
# Processing record 27, barrow
# Processing record 28, araguaina
# Processing record 29, payson
# Processing record 30, ilulissat
# Processing record 31, hithadhoo
# Processing record 32, shingu
# Processing record 33, esperance
# Processing record 34, punta arenas
# Processing record 35, longyearbyen
# Processing record 36, carnarvon
# Processing record 37, vila velha
# Processing record 38, busselton
# Processing record 39, misratah
# Processing record 40, lata
# Processing record 41, atar
# Processing record 42, solnechnyy
# Processing record 43, byron bay
# Processing record 44, sartana
# Processing record 45, kaitangata
# Processing record 46, port alfred
# City not found, skipping
# City not found, skipping
# Processing record 49, hongjiang
# Processing record 50, puerto escondido
# Processing record 51, antsohihy
# Processing record 52, faanui
# Processing record 53, bagdarin
# Processing record 54, new norfolk
# Processing record 55, korla
# Processing record 56, vaini
# Processing record 57, port augusta
# Processing record 58, sao paulo de olivenca
# Processing record 59, hasaki
# Processing record 60, madimba
# Processing record 61, avarua
# Processing record 62, general pico
# Processing record 63, macusani
# City not found, skipping
# Processing record 65, saint-philippe
# Processing record 66, mossendjo
# City not found, skipping
# Processing record 68, georgetown
# Processing record 69, butaritari
# Processing record 70, san patricio
# Processing record 71, dumas
# Processing record 72, manyana
# City not found, skipping
# Processing record 74, severo-kurilsk
# Processing record 75, atuona
# Processing record 76, bethel
# Processing record 77, mehamn
# Processing record 78, shizunai
# City not found, skipping
# Processing record 80, awbari
# Processing record 81, shaowu
# Processing record 82, damietta
# City not found, skipping
# Processing record 84, yellowknife
# Processing record 85, narsaq
# Processing record 86, bairiki
# City not found, skipping
# Processing record 88, tuktoyaktuk
# Processing record 89, lac du bonnet
# Processing record 90, geraldton
# Processing record 91, qaqortoq
# Processing record 92, nanortalik
# Processing record 93, ribeira grande
# City not found, skipping
# Processing record 95, bubaque
# Processing record 96, carutapera
# Processing record 97, lahaina
# City not found, skipping
# Processing record 99, cabo san lucas
# City not found, skipping
# Processing record 101, ati
# Processing record 102, lavrentiya
# City not found, skipping
# Processing record 104, altay
# Processing record 105, anastacio
# Processing record 106, asind
# Processing record 107, inhambane
# Processing record 108, brigantine
# City not found, skipping
# Processing record 110, albany
# Processing record 111, alofi
# Processing record 112, jutai
# Processing record 113, whitecourt
# Processing record 114, ulagan
# Processing record 115, tiksi
# Processing record 116, rapid valley
# Processing record 117, ambagarh chauki
# Processing record 118, hilo
# Processing record 119, khatanga
# City not found, skipping
# Processing record 121, ancud
# Processing record 122, padang
# Processing record 123, talnakh
# Processing record 124, batagay
# Processing record 125, jamestown
# Processing record 126, alta floresta
# Processing record 127, sao raimundo nonato
# Processing record 128, los llanos de aridane
# Processing record 129, meulaboh
# Processing record 130, atambua
# Processing record 131, kavaratti
# Processing record 132, aden
# Processing record 133, mar del plata
# Processing record 134, fredericksburg
# Processing record 135, norman wells
# Processing record 136, fort saint james
# Processing record 137, capitan bado
# Processing record 138, kirakira
# Processing record 139, kongolo
# City not found, skipping
# Processing record 141, komsomolskiy
# Processing record 142, petit goave
# Processing record 143, arraial do cabo
# Processing record 144, luderitz
# Processing record 145, bredasdorp
# Processing record 146, manzhouli
# Processing record 147, safaga
# Processing record 148, lasa
# Processing record 149, beringovskiy
# City not found, skipping
# Processing record 151, port moresby
# Processing record 152, plettenberg bay
# Processing record 153, dalbandin
# Processing record 154, marsh harbour
# Processing record 155, kodiak
# City not found, skipping
# Processing record 157, key biscayne
# Processing record 158, pevek
# Processing record 159, corn island
# City not found, skipping
# Processing record 161, clermont
# Processing record 162, santa cruz
# City not found, skipping
# Processing record 164, bathsheba
# Processing record 165, boueni
# Processing record 166, caravelas
# Processing record 167, ola
# Processing record 168, castro
# Processing record 169, rehoboth
# Processing record 170, saint-pierre
# Processing record 171, wattegama
# Processing record 172, champerico
# Processing record 173, ukiah
# Processing record 174, myrtle beach
# City not found, skipping
# Processing record 176, san cristobal
# Processing record 177, mahebourg
# Processing record 178, vila franca do campo
# Processing record 179, zelenoborskiy
# Processing record 180, husavik
# City not found, skipping
# Processing record 182, ust-maya
# Processing record 183, niquelandia
# Processing record 184, thompson
# Processing record 185, poronaysk
# Processing record 186, price
# Processing record 187, colesberg
# Processing record 188, kavieng
# Processing record 189, colares
# Processing record 190, asau
# Processing record 191, cravo norte
# Processing record 192, tasiilaq
# Processing record 193, mount airy
# Processing record 194, boda
# Processing record 195, cidreira
# Processing record 196, coihaique
# Processing record 197, batemans bay
# Processing record 198, biswan
# Processing record 199, ostrovnoy
# Processing record 200, esil
# Processing record 201, puerto ayora
# Processing record 202, nikolskoye
# Processing record 203, dingle
# Processing record 204, colonia
# Processing record 205, belmonte
# Processing record 206, shelabolikha
# Processing record 207, voyinka
# Processing record 208, chokurdakh
# Processing record 209, lebu
# City not found, skipping
# Processing record 211, ilebo
# Processing record 212, vitim
# Processing record 213, hit
# City not found, skipping
# Processing record 215, shitanjing
# Processing record 216, winchester
# Processing record 217, griffith
# Processing record 218, kjollefjord
# Processing record 219, haines junction
# Processing record 220, tuatapere
# Processing record 221, najran
# City not found, skipping
# Processing record 223, bluff
# City not found, skipping
# Processing record 225, banjarmasin
# Processing record 226, anchorage
# City not found, skipping
# Processing record 228, gubkinskiy
# Processing record 229, cherskiy
# Processing record 230, vestmannaeyjar
# Processing record 231, chuy
# City not found, skipping
# City not found, skipping
# Processing record 234, lagoa
# City not found, skipping
# Processing record 236, upernavik
# Processing record 237, shenjiamen
# Processing record 238, fomboni
# Processing record 239, baykit
# Processing record 240, rocha
# Processing record 241, surin
# Processing record 242, gazojak
# Processing record 243, mount isa
# Processing record 244, muisne
# City not found, skipping
# Processing record 246, zhangye
# Processing record 247, marovoay
# Processing record 248, moundsville
# Processing record 249, olga
# Processing record 250, brownsville
# Processing record 251, taoudenni
# Processing record 252, cascais
# Processing record 253, christchurch
# Processing record 254, hovd
# Processing record 255, rawson
# Processing record 256, kloulklubed
# Processing record 257, iqaluit
# Processing record 258, mihaesti
# Processing record 259, hamilton
# Processing record 260, gizo
# Processing record 261, laela
# Processing record 262, el reten
# Processing record 263, kot samaba
# Processing record 264, igarka
# Processing record 265, chegdomyn
# Processing record 266, provideniya
# Processing record 267, saskylakh
# Processing record 268, sokolac
# Processing record 269, bukene
# Processing record 270, airai
# City not found, skipping
# Processing record 272, ayan
# Processing record 273, sal rei
# Processing record 274, torbay
# Processing record 275, victoria
# Processing record 276, alice springs
# Processing record 277, namibe
# Processing record 278, soyo
# Processing record 279, lacdayan
# Processing record 280, canguaretama
# Processing record 281, peleduy
# Processing record 282, yelovo
# Processing record 283, bud
# City not found, skipping
# Processing record 285, bell ville
# Processing record 286, lac-megantic
# Processing record 287, alice town
# Processing record 288, benguela
# Processing record 289, saint george
# Processing record 290, port-gentil
# Processing record 291, laguna
# City not found, skipping
# Processing record 293, lanzhou
# Processing record 294, zhigansk
# Processing record 295, mporokoso
# Processing record 296, lincoln
# Processing record 297, akdepe
# City not found, skipping
# Processing record 299, conde
# Processing record 300, naze
# Processing record 301, havoysund
# Processing record 302, palana
# Processing record 303, vinh
# Processing record 304, kawalu
# Processing record 305, saint-leu
# Processing record 306, strezhevoy
# Processing record 307, san francisco menendez
# Processing record 308, calvinia
# Processing record 309, isangel
# Processing record 310, melton
# Processing record 311, pisco
# Processing record 312, port lincoln
# Processing record 313, chernyakhiv
# Processing record 314, omaruru
# City not found, skipping
# Processing record 316, burleson
# Processing record 317, sembe
# Processing record 318, mayor pablo lagerenza
# Processing record 319, barceloneta
# Processing record 320, camacha
# City not found, skipping
# Processing record 322, meshchovsk
# Processing record 323, leshukonskoye
# Processing record 324, pemba
# Processing record 325, porto velho
# Processing record 326, mon
# Processing record 327, pacific grove
# Processing record 328, sao joao da barra
# City not found, skipping
# Processing record 330, henties bay
# Processing record 331, cayenne
# Processing record 332, tiznit
# Processing record 333, taltal
# Processing record 334, belyy yar
# Processing record 335, ushirombo
# Processing record 336, clinton
# City not found, skipping
# Processing record 338, nemuro
# Processing record 339, aklavik
# Processing record 340, sistranda
# Processing record 341, tucuman
# Processing record 342, boryslav
# Processing record 343, lashma
# Processing record 344, chaman
# Processing record 345, hereford
# Processing record 346, atbasar
# Processing record 347, sorland
# Processing record 348, eskilstuna
# Processing record 349, severodvinsk
# Processing record 350, andros town
# Processing record 351, clyde river
# Processing record 352, guaruja
# Processing record 353, charleston
# Processing record 354, abu dhabi
# Processing record 355, ramsar
# Processing record 356, bengkulu
# Processing record 357, gondar
# Processing record 358, avera
# City not found, skipping
# Processing record 360, kennett
# Processing record 361, kazerun
# Processing record 362, east london
# Processing record 363, prince rupert
# Processing record 364, kaeo
# Processing record 365, pangnirtung
# Processing record 366, urucui
# Processing record 367, manjacaze
# Processing record 368, maunatlala
# Processing record 369, kruisfontein
# Processing record 370, olinda
# Processing record 371, san lorenzo
# Processing record 372, port elizabeth
# Processing record 373, abonnema
# City not found, skipping
# Processing record 375, vanavara
# Processing record 376, comodoro rivadavia
# Processing record 377, caraquet
# Processing record 378, udachnyy
# Processing record 379, narsingi
# Processing record 380, xichang
# Processing record 381, acapulco
# City not found, skipping
# Processing record 383, chingirlau
# Processing record 384, azanka
# Processing record 385, ichchapuram
# Processing record 386, matagami
# Processing record 387, gornopravdinsk
# Processing record 388, makat
# Processing record 389, balikpapan
# Processing record 390, te anau
# Processing record 391, inverell
# Processing record 392, hambantota
# Processing record 393, sept-iles
# Processing record 394, fort wellington
# Processing record 395, guerrero negro
# Processing record 396, sorong
# Processing record 397, gibara
# Processing record 398, portland
# Processing record 399, quatre cocos
# Processing record 400, petropavlovsk-kamchatskiy
# Processing record 401, saint-georges
# Processing record 402, dawlatabad
# Processing record 403, marawi
# City not found, skipping
# Processing record 405, mahon
# Processing record 406, golden gate
# Processing record 407, lorengau
# Processing record 408, kankon
# Processing record 409, poso
# Processing record 410, salsk
# Processing record 411, sur
# Processing record 412, port shepstone
# Processing record 413, shache
# Processing record 414, kudahuvadhoo
# Processing record 415, do gonbadan
# Processing record 416, nanyang
# Processing record 417, hunterville
# Processing record 418, huarmey
# Processing record 419, sandwick
# Processing record 420, bom jesus da lapa
# Processing record 421, honiara
# Processing record 422, adrar
# Processing record 423, cockburn town
# Processing record 424, verkhoyansk
# Processing record 425, rubizhne
# Processing record 426, jijila
# Processing record 427, kletnya
# Processing record 428, kyra
# Processing record 429, urdoma
# Processing record 430, san jeronimo
# Processing record 431, jinchang
# Processing record 432, nipawin
# Processing record 433, verkhnevilyuysk
# Processing record 434, klaksvik
# Processing record 435, yarada
# Processing record 436, kudat
# Processing record 437, karratha
# Processing record 438, wagar
# Processing record 439, jacksonville
# Processing record 440, mnogovershinnyy
# Processing record 441, pulandian
# Processing record 442, tommot
# Processing record 443, bognor regis
# Processing record 444, poum
# Processing record 445, nishihara
# Processing record 446, ahipara
# Processing record 447, la ronge
# City not found, skipping
# Processing record 449, kahului
# Processing record 450, ust-kan
# Processing record 451, pangkalanbuun
# Processing record 452, katsuura
# Processing record 453, itoman
# Processing record 454, itanagar
# Processing record 455, camalu
# Processing record 456, turki
# Processing record 457, cartagena del chaira
# Processing record 458, itacoatiara
# City not found, skipping
# Processing record 460, pouebo
# Processing record 461, walvis bay
# Processing record 462, gari
# Processing record 463, ugoofaaru
# Processing record 464, arlit
# Processing record 465, flinders
# Processing record 466, trois-rivieres
# Processing record 467, bulungu
# Processing record 468, yokadouma
# Processing record 469, nantucket
# Processing record 470, nagato
# Processing record 471, belinskiy
# Processing record 472, kigoma
# Processing record 473, bismarck
# Processing record 474, nsoko
# Processing record 475, vaitape
# Processing record 476, roma
# Processing record 477, narasannapeta
# Processing record 478, bereda
# Processing record 479, roebourne
# Processing record 480, antibes
# Processing record 481, saldanha
# Processing record 482, abeche
# Processing record 483, kupang
# Processing record 484, sao filipe
# Processing record 485, fairbanks
# Processing record 486, nanchong
# Processing record 487, lourdes
# Processing record 488, raudeberg
# Processing record 489, bastia
# Processing record 490, siderno
# City not found, skipping
# Processing record 492, kurunegala
# Processing record 493, saryozek
# Processing record 494, harrisonburg
# City not found, skipping
# Processing record 496, baykalsk
# Processing record 497, benghazi
# Processing record 498, pingliang
# Processing record 499, karrapur
# Processing record 500, nara
# Processing record 501, sola
# Processing record 502, domoni
# Processing record 503, pocao de pedras
# Processing record 504, capul
# Processing record 505, imeni poliny osipenko
# Processing record 506, canico
# Processing record 507, souillac
# Processing record 508, codrington
# Processing record 509, turbat
# Processing record 510, flin flon
# Processing record 511, chiang mai
# Processing record 512, celestun
# Processing record 513, awjilah
# Processing record 514, rawah
# Processing record 515, iquique
# Processing record 516, wana
# Processing record 517, biskupiec
# City not found, skipping
# City not found, skipping
# Processing record 520, srednekolymsk
# Processing record 521, grand-santi
# Processing record 522, coshocton
# Processing record 523, gannan
# Processing record 524, sitka
# Processing record 525, ternate
# Processing record 526, port hueneme
# Processing record 527, namatanai
# Processing record 528, goma
# Processing record 529, sultanpur
# Processing record 530, coos bay
# Processing record 531, podlesnoye
# City not found, skipping
# Processing record 533, kismayo
# Processing record 534, berlevag
# Processing record 535, aranos
# Processing record 536, bonthe
# Processing record 537, svetlaya
# Processing record 538, sandpoint
# Processing record 539, urumqi
# Processing record 540, masaurhi
# Processing record 541, ballina
# Processing record 542, carahue
# Processing record 543, gat
# Processing record 544, abu zabad
# Processing record 545, bandarbeyla
# Processing record 546, prince george
# Processing record 547, batagay-alyta
# City not found, skipping
# Processing record 549, ampanihy
# City not found, skipping
# Processing record 551, palmer
# Processing record 552, rondonopolis
# Processing record 553, vao
# Processing record 554, ushtobe
# Processing record 555, vila
# Processing record 556, kant
# Processing record 557, ixtapa
# Processing record 558, mayumba
# Processing record 559, skibbereen
# Processing record 560, gilgit
# Processing record 561, fortuna
# Processing record 562, olafsvik
# Processing record 563, lagdo
# Processing record 564, gayeri
# Processing record 565, nova olimpia
# Processing record 566, margate
# Processing record 567, filadelfia
# Processing record 568, thinadhoo
# Processing record 569, arfara
# Processing record 570, coracora
# Processing record 571, yucaipa
# City not found, skipping
# Processing record 573, faya
# Processing record 574, sladkovo
# Processing record 575, north bend
# Processing record 576, xingyi
# City not found, skipping
# Processing record 578, innisfail
# Processing record 579, leningradskiy
# Processing record 580, lompoc
# Processing record 581, hokitika
# Processing record 582, bemidji
# Processing record 583, nabire
# Processing record 584, teya
# Processing record 585, yulara
# Processing record 586, kungurtug
# Processing record 587, alugan
# Processing record 588, zhaotong
# Processing record 589, gorom-gorom
# City not found, skipping
# Processing record 591, geilo
# Processing record 592, lima
# Processing record 593, necochea
# Processing record 594, dunedin
# Processing record 595, ughelli
# Processing record 596, mecca
# Processing record 597, mazatlan
# Processing record 598, new amsterdam
# Processing record 599, piacabucu
# Processing record 600, egvekinot
# Processing record 601, la tuque
# Processing record 602, alyangula
# City not found, skipping
# Processing record 604, waddan
# Processing record 605, port hardy
# Processing record 606, sidvokodvo
# Processing record 607, grindavik
# Processing record 608, bay roberts
# Processing record 609, tateyama
# Processing record 610, riachao das neves
# Processing record 611, nome
# Processing record 612, bilma
# Processing record 613, wexford
# City not found, skipping
# Processing record 615, yantal
# Processing record 616, uruzgan
# Processing record 617, alexandria
# Processing record 618, kitui
# Processing record 619, ongandjera
# Processing record 620, santa maria
# Processing record 621, emerald
# Completed!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# (pd.DataFrame.from_dict(data=weather_data, orient='columns')).to_csv(output_data_file, header=True, index=False)
# df = pd.read_csv(output_data_file)
# df.count()
df = pd.DataFrame.from_dict(data=weather_data, orient='columns')

# %%
def kelvin_to_fahrenheit(k):
    c = float(k) - 273.15
    f = c * (9/5) + 32
    return f

# %%
def mps_to_mph(m):
    """ meter/second convert to mile/hour 
    """
    return 2.23694 * float(m)

# %%
df['Max Temp'] = df['Max Temp'].apply(kelvin_to_fahrenheit)
df['Wind Speed'] = df['Wind Speed'].apply(mps_to_mph)
df.to_csv(output_data_file, header=True, index=False)
print(df.count())
df.head()
# Out:
# City          562
# Cloudiness    562
# Country       562
# Date          562
# Humidity      562
# Lat           562
# Lng           562
# Max Temp      562
# Wind Speed    562
# dtype: int64
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Mahajanga          20      MG  1585698666        88 -15.72   46.32
# 1  Lloydminster          20      CA  1585698435        60  53.28 -110.00
# 2       Salalah          40      OM  1585698667        88  17.02   54.09
# 3        Dikson         100      RU  1585698667        93  73.51   80.55
# 4         Seoul          20      KR  1585697999        34  37.57  126.98
#
#    Max Temp  Wind Speed
# 0    78.800    2.236940
# 1    10.400   16.105968
# 2    80.600    1.118470
# 3    -3.316    4.294925
# 4    51.800    4.227817

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
def draw_scatter(x_data, y_data, title, xlabel, ylabel, savefn, ylimit=None):
    fig, ax = plt.subplots()
    x = x_data
    y = y_data
    ax.scatter(x,y)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_ylim(ylimit)
    ax.grid(True)
    fig.savefig(savefn)

# %%
x = df['Lat']
y = df['Max Temp']
draw_scatter(x, y, 'City Latitude vs. Max Temperature(date)', 'Latitude', 'Max Temperature(F)', './output_data/fig1.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x = df['Lat']
y = df['Humidity']
draw_scatter(x, y, 'City Latitude vs. Humidity (date)', 'Latitude', 'Humidity(%)', "./output_data/fig2.png", (0,300))

# %% [markdown]
# **Latitude vs. Cloudiness Plot**

# %%
x = df['Lat']
y = df['Cloudiness']
draw_scatter(x, y, 'City Latitude vs. Cloudiness (date)', 'Latitude', 'Cloudiness(%)', "./output_data/fig3.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x = df['Lat']
y = df['Wind Speed'].apply(mps_to_mph)
draw_scatter(x, y, 'City Latitude vs. Wind Speed (date)', 'Latitude', 'Wind Speed(mph)', "./output_data/fig4.png", (0,40))

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def draw_scatter_with_linear_reg(x, y, title, xlabel, ylabel, savefn, ylimit=None):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    print(f'slope: {slope:.2f}, intercept: {intercept:.2f}')
    label = f'Y = {slope:.2f}X + {intercept:.2f}'
    print(f'The r-squared is:{r_value**2:.2f}')
    fig, ax = plt.subplots()
    ax.scatter(x,y)
    ax.plot(x, intercept + slope * x, 'r', label=label)
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_ylim(ylimit)
    ax.legend()
    ax.grid(True)
    fig.savefig(savefn)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = df.loc[df['Lat'] >= 0]
southern_hemi_df = df.loc[df['Lat'] < 0]
northern_hemi_df.to_csv('./output_data/north_cities.csv', index=False)
southern_hemi_df.to_csv('./output_data/south_cities.csv', index=False)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
draw_scatter_with_linear_reg(x, y, 'Northern Hemisphere Latitude vs. Max Temp(F)', 'Latitude', 'Max Temp', "./output_data/fig5.png")
# Out:
# slope: -1.18, intercept: 95.67
# The r-squared is:0.83

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
draw_scatter_with_linear_reg(x, y, 'Southern Hemisphere Latitude vs. Max Temp(F)', 'Latitude', 'Max Temp', "./output_data/fig6.png")
# Out:
# slope: 0.43, intercept: 80.99
# The r-squared is:0.36

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
draw_scatter_with_linear_reg(x, y, 'Northern Hemisphere Latitude vs. Humidity(%)', 'Latitude', 'Humidity', './output_data/fig7.png')
# Out:
# slope: 0.30, intercept: 56.55
# The r-squared is:0.07

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
draw_scatter_with_linear_reg(x, y, 'Southern Hemisphere Latitude vs. Humidity(%)', 'Latitude', 'Humidity', './output_data/fig8.png', (0,300))
# Out:
# slope: 0.17, intercept: 77.19
# The r-squared is:0.02

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
draw_scatter_with_linear_reg(x, y, 'Northern Hemisphere Latitude vs. Cloudiness(%)', 'Latitude', 'Cloudiness', './output_data/fig9.png')
# Out:
# slope: 0.27, intercept: 42.76
# The r-squared is:0.02

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
draw_scatter_with_linear_reg(x, y, 'Southern Hemisphere Latitude vs. Cloudiness(%)', 'Latitude', 'Cloudiness', './output_data/fig10.png')
# Out:
# slope: 0.81, intercept: 68.72
# The r-squared is:0.09

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
draw_scatter_with_linear_reg(x, y, 'Northern Hemisphere Latitude vs. Wind Speed (mph)', 'Latitude', 'Wind Speed', './output_data/fig11.png')
# Out:
# slope: 0.05, intercept: 6.83
# The r-squared is:0.02

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
draw_scatter_with_linear_reg(x, y, 'Southern Hemisphere Latitude vs. Wind Speed (mph)', 'Latitude', 'Wind Speed', './output_data/fig12.png', (0,30))
# Out:
# slope: -0.07, intercept: 4.98
# The r-squared is:0.04
